# %%
import os
import sys
import pickle
import argparse

import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn

import torch.multiprocessing
torch.multiprocessing.set_sharing_strategy('file_system')

from utils import avoidWarnings
from beautifultable import BeautifulTable as BT

avoidWarnings()

''' OPTIMIZER PARAMETERS - Analysis on those '''

test = False
best_acc = 0  
start_epoch = 0  
num_epochs = 200  ## TODO: set to args.epochs
batch_size = 128  ## TODO: set to args.barch
milestones = [100, 150]

L = 16
M = 32
E = 7
 
comments = True
n_workers = torch.multiprocessing.cpu_count()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
gpus = True if torch.cuda.device_count() > 1 else False
device_name = torch.cuda.get_device_name(0) if device == 'cuda' else 'CPUs'
    
table = BT()
table.append_row(['Python Version', sys.version[:5]])
table.append_row(['PyTorch Version', torch.__version__])
table.append_row(['Device', str(device_name)])
table.append_row(['Cores', str(n_workers)])
table.append_row(['GPUs', str(torch.cuda.device_count())])
table.append_row(['CUDNN Enabled', str(torch.backends.cudnn.enabled)])
table.append_row(['Architecture', 'DenseNet x7'])
table.append_row(['Dataset', 'CIFAR10'])
table.append_row(['Epochs', str(num_epochs)])
table.append_row(['Batch Size', str(batch_size)])

print(table)
# Out:
# +-----------------+----------------------+
# | Python Version  |        3.6.5         |
# +-----------------+----------------------+
# | PyTorch Version |        1.0.0         |
# +-----------------+----------------------+
# |     Device      | Tesla V100-SXM2-16GB |
# +-----------------+----------------------+
# |      Cores      |          8           |
# +-----------------+----------------------+
# |      GPUs       |          1           |
# +-----------------+----------------------+
# |  CUDNN Enabled  |         True         |
# +-----------------+----------------------+
# |  Architecture   |     DenseNet x7      |
# +-----------------+----------------------+
# |     Dataset     |       CIFAR10        |
# +-----------------+----------------------+
# |     Epochs      |         200          |
# +-----------------+----------------------+
# |   Batch Size    |         128          |
# +-----------------+----------------------+

# %%
# Data
# ----

avoidWarnings()
dataset = 'MNIST'
dataset = 'CIFAR'
from data import dataloaders
trainloader, testloader, classes = dataloaders(dataset, batch_size)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Models 
# ------
    
# For now, NO SHARING of any layers withing the ensemble

avoidWarnings()
from models import Conv_Net
from utils import count_parameters
net = Conv_Net('net', layers=L, filters=M)

print('Regular net')
print('\n\n\t\tParameters: {}M'.format(count_parameters(net)/1e6))

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-5)
# Out:
# Regular net
#
#
# 		Parameters: 0.174762M

# %%
# Training
# --------

from utils import timeit
from results import TrainResults as Results

def train(epoch):
    
    net.train()
    print('\nEpoch: %d' % epoch)

    total = 0
    correct = 0
    global results
    
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        
        optimizer.zero_grad()

        inputs, targets = inputs.to(device), targets.to(device)
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        
        loss.backward()
        optimizer.step()
    
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
    
    accuracy = 100.*correct/total    
    results.append_loss(loss.item(), 'train')
    results.append_accy(accuracy, 'train')    
    print('Train :: Loss: {} | Accy: {}'.format(round(loss.item(),2), round(accuracy,2)))

        
def test(epoch):
    
    net.eval()

    total = 0
    correct = 0
    global results
    global best_acc

    with torch.no_grad():
        
        for batch_idx, (inputs, targets) in enumerate(testloader):
            
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
            
    # Save checkpoint.
    acc = 100.*correct/total
    results.append_loss(loss.item(), 'valid')
    results.append_accy(acc, 'valid')
    print('Valid :: Loss: {} | Accy: {}'.format(round(loss.item(),2), round(acc,2)))
    
    if acc > best_acc:
        print('Saving..')
        state = {
            'net': net.state_dict(),
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/ckpt.t7')
        best_acc = acc

# %%
def lr_schedule(epoch):

    global milestones
    if epoch == milestones[0] or epoch == milestones[1]:
        for p in optimizer.param_groups:  p['lr'] = p['lr'] / 10
        print('\n** Changing LR to {} \n'.format(p['lr']))    
    return
    
def results_backup(epoch):
    # Save every X epochs in case training breaks we don't loose results    
    global results
    if epoch % 20 == 0:
        with open('Results_Singe.pkl', 'wb') as object_result:
                pickle.dump(results, object_result, pickle.HIGHEST_PROTOCOL)     

@timeit
def run_epoch(epoch):
    
    lr_schedule(epoch)
    train(epoch)
    test(epoch)
    results_backup(epoch)

# %%
# Send model to GPU(s)
    
results = Results([net])
net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

# %%
# Start training
    
print('[OK]: Starting Training of Single Model')
for epoch in range(start_epoch, num_epochs):
    run_epoch(epoch)

    
results.show()
# Out:
# [OK]: Starting Training of Single Model
#
# Epoch: 0
# Train :: Loss: 1.76 | Accy: 28.23
# Valid :: Loss: 1.65 | Accy: 39.48
# Saving..
# 'run_epoch'  11280.72 ms
#
# Epoch: 1
# Train :: Loss: 1.5 | Accy: 39.9
# Valid :: Loss: 1.57 | Accy: 44.09
# Saving..
# 'run_epoch'  11218.48 ms
#
# Epoch: 2
# Train :: Loss: 1.42 | Accy: 45.27
# Valid :: Loss: 1.43 | Accy: 48.28
# Saving..
# 'run_epoch'  11126.44 ms
#
# Epoch: 3
# Train :: Loss: 1.34 | Accy: 49.21
# Valid :: Loss: 1.28 | Accy: 53.66
# Saving..
# 'run_epoch'  11628.81 ms
#
# Epoch: 4
# Train :: Loss: 1.45 | Accy: 51.25
# Valid :: Loss: 1.38 | Accy: 51.72
# 'run_epoch'  11515.21 ms
#
# Epoch: 5
# Train :: Loss: 1.51 | Accy: 53.79
# Valid :: Loss: 1.28 | Accy: 56.68
# Saving..
# 'run_epoch'  11487.70 ms
#
# Epoch: 6
# Train :: Loss: 1.28 | Accy: 56.07
# Valid :: Loss: 1.34 | Accy: 58.89
# Saving..
# 'run_epoch'  11278.56 ms
#
# Epoch: 7
# Train :: Loss: 1.28 | Accy: 57.85
# Valid :: Loss: 1.17 | Accy: 59.69
# Saving..
# 'run_epoch'  11407.72 ms
#
# Epoch: 8
# Train :: Loss: 0.93 | Accy: 59.25
# Valid :: Loss: 1.11 | Accy: 62.33
# Saving..
# 'run_epoch'  11512.52 ms
#
# Epoch: 9
# Train :: Loss: 1.16 | Accy: 60.02
# Valid :: Loss: 1.2 | Accy: 63.04
# Saving..
# 'run_epoch'  11116.02 ms
#
# Epoch: 10
# Train :: Loss: 0.96 | Accy: 61.49
# Valid :: Loss: 1.22 | Accy: 62.51
# 'run_epoch'  10972.32 ms
#
# Epoch: 11
# Train :: Loss: 1.13 | Accy: 62.68
# Valid :: Loss: 1.06 | Accy: 64.2
# Saving..
# 'run_epoch'  11499.75 ms
#
# Epoch: 12
# Train :: Loss: 1.15 | Accy: 63.68
# Valid :: Loss: 1.12 | Accy: 64.98
# Saving..
# 'run_epoch'  11120.19 ms
#
# Epoch: 13
# Train :: Loss: 1.3 | Accy: 64.34
# Valid :: Loss: 1.12 | Accy: 64.71
# 'run_epoch'  11288.97 ms
#
# Epoch: 14
# Train :: Loss: 1.06 | Accy: 65.15
# Valid :: Loss: 1.01 | Accy: 63.37
# 'run_epoch'  11233.12 ms
#
# Epoch: 15
# Train :: Loss: 1.06 | Accy: 65.62
# Valid :: Loss: 1.1 | Accy: 66.49
# Saving..
# 'run_epoch'  11147.58 ms
#
# Epoch: 16
# Train :: Loss: 0.97 | Accy: 66.54
# Valid :: Loss: 0.96 | Accy: 68.14
# Saving..
# 'run_epoch'  11481.49 ms
#
# Epoch: 17
# Train :: Loss: 0.79 | Accy: 66.71
# Valid :: Loss: 1.15 | Accy: 66.07
# 'run_epoch'  11445.11 ms
#
# Epoch: 18
# Train :: Loss: 0.93 | Accy: 67.54
# Valid :: Loss: 0.89 | Accy: 68.24
# Saving..
# 'run_epoch'  11195.38 ms
#
# Epoch: 19
# Train :: Loss: 0.86 | Accy: 67.86
# Valid :: Loss: 0.92 | Accy: 69.65
# Saving..
# 'run_epoch'  11615.05 ms
#
# Epoch: 20
# Train :: Loss: 0.78 | Accy: 68.51
# Valid :: Loss: 0.88 | Accy: 68.91
# 'run_epoch'  11249.53 ms
#
# Epoch: 21
# Train :: Loss: 0.58 | Accy: 68.92
# Valid :: Loss: 0.94 | Accy: 69.24
# 'run_epoch'  11425.96 ms
#
# Epoch: 22
# Train :: Loss: 0.87 | Accy: 69.51
# Valid :: Loss: 0.89 | Accy: 69.17
# 'run_epoch'  11367.57 ms
#
# Epoch: 23
# Train :: Loss: 1.08 | Accy: 69.69
# Valid :: Loss: 0.9 | Accy: 68.66
# 'run_epoch'  11468.57 ms
#
# Epoch: 24
# Train :: Loss: 0.77 | Accy: 70.16
# Valid :: Loss: 0.89 | Accy: 70.59
# Saving..
# 'run_epoch'  11216.81 ms
#
# Epoch: 25
# Train :: Loss: 0.66 | Accy: 70.86
# Valid :: Loss: 0.83 | Accy: 71.03
# Saving..
# 'run_epoch'  11322.98 ms
#
# Epoch: 26
# Train :: Loss: 0.87 | Accy: 70.75
# Valid :: Loss: 0.86 | Accy: 72.31
# Saving..
# 'run_epoch'  11484.21 ms
#
# Epoch: 27
# Train :: Loss: 0.87 | Accy: 71.1
# Valid :: Loss: 0.87 | Accy: 71.37
# 'run_epoch'  11248.03 ms
#
# Epoch: 28
# Train :: Loss: 0.66 | Accy: 71.33
# Valid :: Loss: 0.85 | Accy: 71.1
# 'run_epoch'  11681.73 ms
#
# Epoch: 29
# Train :: Loss: 0.84 | Accy: 71.7
# Valid :: Loss: 0.92 | Accy: 71.05
# 'run_epoch'  11332.24 ms
#
# Epoch: 30
# Train :: Loss: 0.82 | Accy: 71.74
# Valid :: Loss: 0.85 | Accy: 71.53
# 'run_epoch'  11435.53 ms
#
# Epoch: 31
# Train :: Loss: 0.57 | Accy: 72.39
# Valid :: Loss: 0.77 | Accy: 71.54
# 'run_epoch'  11494.86 ms
#
# Epoch: 32
# Train :: Loss: 0.56 | Accy: 72.61
# Valid :: Loss: 0.93 | Accy: 72.25
# 'run_epoch'  11159.58 ms
#
# Epoch: 33
# Train :: Loss: 1.02 | Accy: 72.59
# Valid :: Loss: 0.85 | Accy: 72.43
# Saving..
# 'run_epoch'  11466.66 ms
#
# Epoch: 34
# Train :: Loss: 0.76 | Accy: 73.04
# Valid :: Loss: 0.87 | Accy: 73.29
# Saving..
# 'run_epoch'  11222.55 ms
#
# Epoch: 35
# Train :: Loss: 0.86 | Accy: 73.08
# Valid :: Loss: 0.95 | Accy: 73.26
# 'run_epoch'  11521.23 ms
#
# Epoch: 36
# Train :: Loss: 0.66 | Accy: 73.68
# Valid :: Loss: 0.88 | Accy: 72.81
# 'run_epoch'  11459.34 ms
#
# Epoch: 37
# Train :: Loss: 1.01 | Accy: 73.76
# Valid :: Loss: 0.94 | Accy: 71.77
# 'run_epoch'  11164.76 ms
#
# Epoch: 38
# Train :: Loss: 0.68 | Accy: 73.91
# Valid :: Loss: 0.75 | Accy: 73.18
# 'run_epoch'  11230.11 ms
#
# Epoch: 39
# Train :: Loss: 0.82 | Accy: 74.21
# Valid :: Loss: 0.8 | Accy: 72.65
# 'run_epoch'  11614.99 ms
#
# Epoch: 40
# Train :: Loss: 0.78 | Accy: 74.34
# Valid :: Loss: 0.9 | Accy: 72.74
# 'run_epoch'  11296.59 ms
#
# Epoch: 41
# Train :: Loss: 0.9 | Accy: 74.28
# Valid :: Loss: 0.74 | Accy: 73.51
# Saving..
# 'run_epoch'  11069.55 ms
#
# Epoch: 42
# Train :: Loss: 0.88 | Accy: 74.49
# Valid :: Loss: 0.91 | Accy: 74.09
# Saving..
# 'run_epoch'  11513.34 ms
#
# Epoch: 43
# Train :: Loss: 0.63 | Accy: 74.76
# Valid :: Loss: 0.81 | Accy: 74.82
# Saving..
# 'run_epoch'  11257.62 ms
#
# Epoch: 44
# Train :: Loss: 0.65 | Accy: 74.7
# Valid :: Loss: 0.86 | Accy: 73.56
# 'run_epoch'  11448.83 ms
#
# Epoch: 45
# Train :: Loss: 0.87 | Accy: 74.66
# Valid :: Loss: 0.92 | Accy: 74.28
# 'run_epoch'  11152.33 ms
#
# Epoch: 46
# Train :: Loss: 0.67 | Accy: 75.42
# Valid :: Loss: 0.8 | Accy: 74.7
# 'run_epoch'  11363.99 ms
#
# Epoch: 47
# Train :: Loss: 0.95 | Accy: 75.51
# Valid :: Loss: 0.85 | Accy: 74.69
# 'run_epoch'  11419.98 ms
#
# Epoch: 48
# Train :: Loss: 0.62 | Accy: 75.55
# Valid :: Loss: 0.82 | Accy: 74.76
# 'run_epoch'  11312.80 ms
#
# Epoch: 49
# Train :: Loss: 0.62 | Accy: 75.71
# Valid :: Loss: 0.86 | Accy: 74.87
# Saving..
# 'run_epoch'  11284.29 ms
#
# Epoch: 50
# Train :: Loss: 0.58 | Accy: 75.65
# Valid :: Loss: 0.83 | Accy: 75.46
# Saving..
# 'run_epoch'  11588.57 ms
#
# Epoch: 51
# Train :: Loss: 0.88 | Accy: 76.09
# Valid :: Loss: 0.79 | Accy: 75.21
# 'run_epoch'  11484.73 ms
#
# Epoch: 52

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(len(results.train_loss)), results.train_loss, label='Train')
plt.plot(range(len(results.valid_loss)), results.valid_loss, label='Valid')
plt.title('Loss')
plt.show()

plt.figure()
plt.plot(range(len(results.train_accy)), results.train_accy, label='Train')
plt.plot(range(len(results.valid_accy)), results.valid_accy, label='Valid')

plt.title('Accuracy')
plt.show()
