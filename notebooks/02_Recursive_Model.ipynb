# %%
import os
import sys
import pickle
import argparse

import torch
import torch.nn as nn
import torch.optim as optim
import torch.backends.cudnn as cudnn

import torch.multiprocessing
torch.multiprocessing.set_sharing_strategy('file_system')

from utils import avoidWarnings
from beautifultable import BeautifulTable as BT

avoidWarnings()

''' OPTIMIZER PARAMETERS - Analysis on those '''

test = False
best_acc = 0  
start_epoch = 0  
num_epochs = 200  ## TODO: set to args.epochs
batch_size = 128  ## TODO: set to args.barch
milestones = [100, 150]

L = 16
M = 32
E = 7
 
comments = True
n_workers = torch.multiprocessing.cpu_count()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
gpus = True if torch.cuda.device_count() > 1 else False
device_name = torch.cuda.get_device_name(0) if device == 'cuda' else 'CPUs'
    
table = BT()
table.append_row(['Python Version', sys.version[:5]])
table.append_row(['PyTorch Version', torch.__version__])
table.append_row(['Device', str(device_name)])
table.append_row(['Cores', str(n_workers)])
table.append_row(['GPUs', str(torch.cuda.device_count())])
table.append_row(['CUDNN Enabled', str(torch.backends.cudnn.enabled)])
table.append_row(['Architecture', 'DenseNet x7'])
table.append_row(['Dataset', 'CIFAR10'])
table.append_row(['Epochs', str(num_epochs)])
table.append_row(['Batch Size', str(batch_size)])

print(table)
# Out:
# +-----------------+----------------------+
# | Python Version  |        3.6.5         |
# +-----------------+----------------------+
# | PyTorch Version |        1.0.0         |
# +-----------------+----------------------+
# |     Device      | Tesla V100-SXM2-16GB |
# +-----------------+----------------------+
# |      Cores      |          8           |
# +-----------------+----------------------+
# |      GPUs       |          1           |
# +-----------------+----------------------+
# |  CUDNN Enabled  |         True         |
# +-----------------+----------------------+
# |  Architecture   |     DenseNet x7      |
# +-----------------+----------------------+
# |     Dataset     |       CIFAR10        |
# +-----------------+----------------------+
# |     Epochs      |         200          |
# +-----------------+----------------------+
# |   Batch Size    |         128          |
# +-----------------+----------------------+

# %%
# Data
# ----

avoidWarnings()
dataset = 'MNIST'
dataset = 'CIFAR'
from data import dataloaders
trainloader, testloader, classes = dataloaders(dataset, batch_size)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Models 
# ------
    
avoidWarnings()
comments = True
from utils import count_parameters
from models import Conv_Recusive_Net
net = Conv_Recusive_Net('recursive_net', layers=L, filters=M)


print('Recursive ConvNet')
if comments: print(net)
print('\n\n\t\tParameters: {}M'.format(count_parameters(net)/1e6))

optimizers = []
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-5)
# Out:
# Recursive ConvNet
# Conv_Recusive_Net(
#   (act): ReLU(inplace)
#   (V): Conv2d(3, 32, kernel_size=(8, 8), stride=(1, 1), padding=(3, 3))
#   (P): MaxPool2d(kernel_size=4, stride=4, padding=2, dilation=1, ceil_mode=False)
#   (W): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc): Linear(in_features=2048, out_features=10, bias=True)
# )
#
#
# 		Parameters: 0.035914M

# %%
# Training
# --------
    
# Helpers
from utils import timeit
from results import TrainResults as Results


def train(epoch):
    
    net.train()
    print('\nEpoch: %d' % epoch)

    total = 0
    correct = 0
    global results
    
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        
        optimizer.zero_grad()

        inputs, targets = inputs.to(device), targets.to(device)
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        
        loss.backward()
        optimizer.step()
    
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        ## TODO: UNCOMMENT WHEN RUNNING ON SERVER - It just for debuggin on local
        if testing and batch_idx == 5:
            break
    
    accuracy = 100.*correct/total    
    results.append_loss(round(loss.item(),2), 'train')
    results.append_accy(round(accuracy,2), 'train')    
    print('Train :: Loss: {} | Accy: {}'.format(round(loss.item(),2), round(accuracy,2)))

        
def test(epoch):
    
    net.eval()

    total = 0
    correct = 0
    global results
    global best_acc

    with torch.no_grad():
        
        for batch_idx, (inputs, targets) in enumerate(testloader):
            
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
            
            # TODO: UNCOMMENT WHEN RUNNING ON SERVER -> wraped in test parameter
            if testing and batch_idx == 5:
                break
            
    # Save checkpoint.
    acc = 100.*correct/total
    results.append_loss(round(loss.item(),2), 'valid')
    results.append_accy(round(acc,2), 'valid')
    print('Valid :: Loss: {} | Accy: {}'.format(round(loss.item(),2), round(acc,2)))
    
    if acc > best_acc:
        print('Saving..')
        state = {
            'net': net.state_dict(),
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/rec_ckpt.t7')
        best_acc = acc


def lr_schedule(epoch):

    global milestones
    if epoch in milestones:
        for p in optimizer.param_groups:  p['lr'] = p['lr'] / 10
        print('\n** Changing LR to {} \n'.format(p['lr']))    
    return

# %%
path = '../results/single_recursive_model/Results_Single_Recursive.pkl'
def results_backup():
    global results
    with open(path, 'wb') as object_result:
        pickle.dump(results, object_result, pickle.HIGHEST_PROTOCOL)

# %%
@timeit
def run_epoch(epoch):
    
    lr_schedule(epoch)
    train(epoch)
    test(epoch)
    results_backup()

# %%
# Send model to GPU(s)
    
results = Results([net])
net.to(device)
if device == 'cuda':
    net = torch.nn.DataParallel(net)
    cudnn.benchmark = True

# %%
# Start training
   
testing = False
print('[OK]: Starting Training of Single Model')
for epoch in range(start_epoch, num_epochs):
    run_epoch(epoch)
    
results.show()
# Out:
# [OK]: Starting Training of Single Model
#
# Epoch: 0
# Train :: Loss: 2.3 | Accy: 9.9
# Valid :: Loss: 2.3 | Accy: 10.0
# Saving..
# 'run_epoch'  9355.07 ms
#
# Epoch: 1
# Train :: Loss: 2.3 | Accy: 9.82
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9562.82 ms
#
# Epoch: 2
# Train :: Loss: 2.3 | Accy: 9.81
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9610.84 ms
#
# Epoch: 3
# Train :: Loss: 2.3 | Accy: 9.95
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9311.90 ms
#
# Epoch: 4
# Train :: Loss: 2.3 | Accy: 9.78
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9248.70 ms
#
# Epoch: 5
# Train :: Loss: 2.3 | Accy: 9.83
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9317.80 ms
#
# Epoch: 6
# Train :: Loss: 2.3 | Accy: 9.82
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9195.69 ms
#
# Epoch: 7
# Train :: Loss: 2.3 | Accy: 9.8
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9908.25 ms
#
# Epoch: 8
# Train :: Loss: 2.3 | Accy: 9.99
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9271.81 ms
#
# Epoch: 9
# Train :: Loss: 2.3 | Accy: 9.88
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9575.86 ms
#
# Epoch: 10
# Train :: Loss: 2.31 | Accy: 9.85
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9408.70 ms
#
# Epoch: 11
# Train :: Loss: 2.3 | Accy: 9.69
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9092.67 ms
#
# Epoch: 12
# Train :: Loss: 2.3 | Accy: 9.52
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  8964.41 ms
#
# Epoch: 13
# Train :: Loss: 2.3 | Accy: 9.79
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9211.68 ms
#
# Epoch: 14
# Train :: Loss: 2.3 | Accy: 9.98
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9379.41 ms
#
# Epoch: 15
# Train :: Loss: 2.3 | Accy: 9.97
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9238.79 ms
#
# Epoch: 16
# Train :: Loss: 2.31 | Accy: 9.84
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9285.71 ms
#
# Epoch: 17
# Train :: Loss: 2.3 | Accy: 9.89
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9363.88 ms
#
# Epoch: 18
# Train :: Loss: 2.3 | Accy: 10.0
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9390.20 ms
#
# Epoch: 19
# Train :: Loss: 2.3 | Accy: 9.67
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  8976.63 ms
#
# Epoch: 20
# Train :: Loss: 2.3 | Accy: 9.9
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9229.85 ms
#
# Epoch: 21
# Train :: Loss: 2.3 | Accy: 9.94
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9355.95 ms
#
# Epoch: 22
# Train :: Loss: 2.3 | Accy: 9.91
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9034.30 ms
#
# Epoch: 23
# Train :: Loss: 2.3 | Accy: 9.98
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  10014.24 ms
#
# Epoch: 24
# Train :: Loss: 2.3 | Accy: 10.09
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9187.98 ms
#
# Epoch: 25
# Train :: Loss: 2.3 | Accy: 9.9
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9236.61 ms
#
# Epoch: 26
# Train :: Loss: 2.3 | Accy: 9.78
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9322.91 ms
#
# Epoch: 27
# Train :: Loss: 2.3 | Accy: 9.95
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9346.55 ms
#
# Epoch: 28
# Train :: Loss: 2.3 | Accy: 9.82
# Valid :: Loss: 2.31 | Accy: 10.0
# 'run_epoch'  9209.89 ms
#
# Epoch: 29
# Train :: Loss: 2.3 | Accy: 9.86
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9152.16 ms
#
# Epoch: 30
# Train :: Loss: 2.3 | Accy: 9.92
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9275.84 ms
#
# Epoch: 31
# Train :: Loss: 2.3 | Accy: 9.79
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9174.99 ms
#
# Epoch: 32
# Train :: Loss: 2.3 | Accy: 10.01
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9191.47 ms
#
# Epoch: 33
# Train :: Loss: 2.3 | Accy: 9.94
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9470.90 ms
#
# Epoch: 34
# Train :: Loss: 2.3 | Accy: 9.77
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9450.47 ms
#
# Epoch: 35
# Train :: Loss: 2.3 | Accy: 9.83
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9228.67 ms
#
# Epoch: 36
# Train :: Loss: 2.3 | Accy: 9.88
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9138.06 ms
#
# Epoch: 37
# Train :: Loss: 2.3 | Accy: 9.7
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9262.57 ms
#
# Epoch: 38
# Train :: Loss: 2.3 | Accy: 9.81
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9769.73 ms
#
# Epoch: 39
# Train :: Loss: 2.3 | Accy: 9.68
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9426.67 ms
#
# Epoch: 40
# Train :: Loss: 2.3 | Accy: 9.82
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9194.10 ms
#
# Epoch: 41
# Train :: Loss: 2.3 | Accy: 10.03
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9262.30 ms
#
# Epoch: 42
# Train :: Loss: 2.3 | Accy: 9.71
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9144.02 ms
#
# Epoch: 43
# Train :: Loss: 2.3 | Accy: 9.78
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9426.93 ms
#
# Epoch: 44
# Train :: Loss: 2.3 | Accy: 9.78
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9305.75 ms
#
# Epoch: 45
# Train :: Loss: 2.3 | Accy: 9.59
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9275.18 ms
#
# Epoch: 46
# Train :: Loss: 2.3 | Accy: 9.75
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9038.41 ms
#
# Epoch: 47
# Train :: Loss: 2.3 | Accy: 9.78
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9126.75 ms
#
# Epoch: 48
# Train :: Loss: 2.3 | Accy: 9.97
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9818.98 ms
#
# Epoch: 49
# Train :: Loss: 2.3 | Accy: 9.81
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9167.33 ms
#
# Epoch: 50
# Train :: Loss: 2.3 | Accy: 9.89
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9488.65 ms
#
# Epoch: 51
# Train :: Loss: 2.3 | Accy: 9.76
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9229.14 ms
#
# Epoch: 52
# Train :: Loss: 2.3 | Accy: 9.69
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9303.51 ms
#
# Epoch: 53
# Train :: Loss: 2.3 | Accy: 9.97
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9303.51 ms
#
# Epoch: 54
# Train :: Loss: 2.3 | Accy: 10.04
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  8999.74 ms
#
# Epoch: 55
# Train :: Loss: 2.3 | Accy: 9.81
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9270.63 ms
#
# Epoch: 56
# Train :: Loss: 2.3 | Accy: 9.69
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9730.03 ms
#
# Epoch: 57
# Train :: Loss: 2.3 | Accy: 9.69
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9648.61 ms
#
# Epoch: 58
# Train :: Loss: 2.3 | Accy: 10.02
# Valid :: Loss: 2.31 | Accy: 10.0
# 'run_epoch'  9069.15 ms
#
# Epoch: 59
# Train :: Loss: 2.3 | Accy: 9.91
# Valid :: Loss: 2.31 | Accy: 10.0
# 'run_epoch'  9229.26 ms
#
# Epoch: 60
# Train :: Loss: 2.3 | Accy: 9.87
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9373.53 ms
#
# Epoch: 61
# Train :: Loss: 2.3 | Accy: 9.77
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9705.15 ms
#
# Epoch: 62
# Train :: Loss: 2.3 | Accy: 9.74
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9072.49 ms
#
# Epoch: 63
# Train :: Loss: 2.3 | Accy: 9.65
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9424.66 ms
#
# Epoch: 64
# Train :: Loss: 2.3 | Accy: 9.57
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9336.90 ms
#
# Epoch: 65
# Train :: Loss: 2.3 | Accy: 10.14
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9214.06 ms
#
# Epoch: 66
# Train :: Loss: 2.3 | Accy: 9.84
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9287.03 ms
#
# Epoch: 67
# Train :: Loss: 2.3 | Accy: 9.81
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9728.24 ms
#
# Epoch: 68
# Train :: Loss: 2.3 | Accy: 9.8
# Valid :: Loss: 2.3 | Accy: 10.0
# 'run_epoch'  9774.92 ms
#
# Epoch: 69
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-1513bb715e23> in <module>()
#       4 print('[OK]: Starting Training of Single Model')
#       5 for epoch in range(start_epoch, num_epochs):
# ----> 6     run_epoch(epoch)
#       7
#       8 results.show()
#
# ~/Recursive_Networks/scripts/utils.py in timed(*args, **kw)
#      18     def timed(*args, **kw):
#      19         ts = time.time()
# ---> 20         result = method(*args, **kw)
#      21         te = time.time()
#      22         if 'log_time' in kw:
#
# <ipython-input-13-ecd5a637f121> in run_epoch(epoch)
#       3
#       4     lr_schedule(epoch)
# ----> 5     train(epoch)
#       6     test(epoch)
#       7     results_backup()
#
# <ipython-input-11-d8d0ad8d8f81> in train(epoch)
#      16     global results
#      17
# ---> 18     for batch_idx, (inputs, targets) in enumerate(trainloader):
#      19
#      20         optimizer.zero_grad()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     629         while True:
#     630             assert (not self.shutdown and self.batches_outstanding > 0)
# --> 631             idx, batch = self._get_batch()
#     632             self.batches_outstanding -= 1
#     633             if idx != self.rcvd_idx:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_batch(self)
#     608             # need to call `.task_done()` because we don't use `.join()`.
#     609         else:
# --> 610             return self.data_queue.get()
#     611
#     612     def __next__(self):
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/multiprocessing/queues.py in get(self, block, timeout)
#      92         if block and timeout is None:
#      93             with self._rlock:
# ---> 94                 res = self._recv_bytes()
#      95             self._sem.release()
#      96         else:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/multiprocessing/connection.py in recv_bytes(self, maxlength)
#     214         if maxlength is not None and maxlength < 0:
#     215             raise ValueError("negative maxlength")
# --> 216         buf = self._recv_bytes(maxlength)
#     217         if buf is None:
#     218             self._bad_message_length()
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(len(results.train_loss)), results.train_loss, label='Train')
plt.plot(range(len(results.valid_loss)), results.valid_loss, label='Valid')
plt.title('Loss')
plt.show()

plt.figure()
plt.plot(range(len(results.train_accy)), results.train_accy, label='Train')
plt.plot(range(len(results.valid_accy)), results.valid_accy, label='Valid')

plt.title('Accuracy')
plt.show()
